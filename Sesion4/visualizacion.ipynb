# %%
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns

# %%
#grafico de lineas
x = [1,2,3,4,5]
y = [2,6,9,4,11]
#ver video en 02:38

plt.plot(x,y)
plt.xlabel('eje x')
plt.ylabel('eje y')
plt.title('primer gafico lineal')
plt.show()
